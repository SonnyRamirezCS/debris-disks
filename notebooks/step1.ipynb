# %%
import numpy, pandas, matplotlib, astropy, sklearn
for m in [numpy, pandas, matplotlib, astropy, sklearn]:
    print(m.__name__, m.__version__)
# Out:
# numpy 2.5.3
# pandas 3.0.6
# matplotlib 3.11.2
# astropy 8.0.1
# sklearn 1.9.1
